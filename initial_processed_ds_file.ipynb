# %%
import pandas as pd

# %%
df = pd.read_csv("/content/FLresults.csv")

# %%
df.head()
# Out:
#    model                                    hyperparameters  dataset_name  \
# 0  Lasso  {'alpha': 1e-05, 'copy_X': True, 'fit_intercep...             8
# 1  Lasso  {'alpha': 1e-05, 'copy_X': True, 'fit_intercep...             1
# 2  Lasso  {'alpha': 1e-05, 'copy_X': True, 'fit_intercep...             1
# 3  Lasso  {'alpha': 1.52333050070436e-05, 'copy_X': True...             1
# 4  Lasso  {'alpha': 1.52333050070436e-05, 'copy_X': True...             1
#
#    num_clients  best_loss  train_rmse  time_taken
# 0            4   0.247223    0.236833    0.004000
# 1            5   0.410856    0.357683    0.004859
# 2            5   0.203307    0.224944    0.008270
# 3            5   0.203307    0.224944    0.006675
# 4            5   0.203307    0.224944    0.007128

# %%
datasets_list = df['dataset_name'].unique()

# %%
datasets_list
# Out:
# array([  8,   1, 107, 109, 111, 112, 114, 118,  12, 120, 121, 123, 124,
#        125, 126, 127, 128, 130, 131, 132, 135, 136, 139,  14, 140, 143,
#        144, 147, 148, 150, 154, 155, 156, 157, 158, 159, 161])

# %%
filenames = [str(num) + ".csv" for num in datasets_list]

# %%
for filename in filenames:
    print(filename)
# Out:
# 8.csv
# 1.csv
# 107.csv
# 109.csv
# 111.csv
# 112.csv
# 114.csv
# 118.csv
# 12.csv
# 120.csv
# 121.csv
# 123.csv
# 124.csv
# 125.csv
# 126.csv
# 127.csv
# 128.csv
# 130.csv
# 131.csv
# 132.csv
# 135.csv
# 136.csv
# 139.csv
# 14.csv
# 140.csv
# 143.csv
# 144.csv
# 147.csv
# 148.csv
# 150.csv
# 154.csv
# 155.csv
# 156.csv
# 157.csv
# 158.csv
# 159.csv
# 161.csv
